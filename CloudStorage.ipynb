# %% [markdown]
# <a href="https://colab.research.google.com/github/sukamadev/analise-de-dados/blob/main/CloudStorage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando pandas
import pandas as pd

# lendo um arquivo de extensão csv
df = pd.read_csv('https://storage.googleapis.com/sukama-bucket/dfs_brutos/alunos_matriculados%20-%20Pa%CC%81gina1%20(1).csv')
# mostrando a dataframe
display(df)
# Out:
#    matricula               nome  idade          cidade    pais  \
# 0       1001         João Silva     29       São Paulo  Brasil
# 1       1002     Maria Oliveira     34  Rio de Janeiro  Brasil
# 2       1003       Pedro Santos     22  Belo Horizonte  Brasil
# 3       1004          Ana Costa     27        Salvador  Brasil
# 4       1005     Carlos Pereira     31       Fortaleza  Brasil
# 5       1006    Laura Rodrigues     25        Curitiba  Brasil
# 6       1007      Bruno Almeida     28    Porto Alegre  Brasil
# 7       1009    Felipe Oliveira     40        Brasília  Brasil
# 8       1010  Juliana Fernandes     26        Campinas  Brasil
#
#                          email      departamento                cargo  salario
# 0         joao.silva@email.com  Recursos Humanos             Analista     4500
# 1     maria.oliveira@email.com        Financeiro         Coordenadora     6200
# 2       pedro.santos@email.com                TI        Desenvolvedor     3500
# ...

# %%
# saber quantidade de linhas e colunas na tabela
df.shape
# Out:
# (9, 9)

# %%
# exibe 0 cabeçalho e a quantidade de linhas informadas, default=5
df.head(4)
# Out:
#    matricula            nome  idade          cidade    pais  \
# 0       1001      João Silva     29       São Paulo  Brasil
# 1       1002  Maria Oliveira     34  Rio de Janeiro  Brasil
# 2       1003    Pedro Santos     22  Belo Horizonte  Brasil
# 3       1004       Ana Costa     27        Salvador  Brasil
#
#                       email      departamento          cargo  salario
# 0      joao.silva@email.com  Recursos Humanos       Analista     4500
# 1  maria.oliveira@email.com        Financeiro   Coordenadora     6200
# 2    pedro.santos@email.com                TI  Desenvolvedor     3500
# 3       ana.costa@email.com         Marketing     Assistente     4000

# %%
# exibe as últimas linhas informadas, default=5
df.tail()
# Out:
#    matricula               nome  idade        cidade    pais  \
# 4       1005     Carlos Pereira     31     Fortaleza  Brasil
# 5       1006    Laura Rodrigues     25      Curitiba  Brasil
# 6       1007      Bruno Almeida     28  Porto Alegre  Brasil
# 7       1009    Felipe Oliveira     40      Brasília  Brasil
# 8       1010  Juliana Fernandes     26      Campinas  Brasil
#
#                          email      departamento                cargo  salario
# 4     carlos.pereira@email.com         Logística           Supervisor     5000
# 5    laura.rodrigues@email.com  Recursos Humanos           Assistente     3800
# 6      bruno.almeida@email.com        Financeiro             Analista     4700
# 7    felipe.oliveira@email.com                TI  Gerente de Projetos     7000
# 8  juliana.fernandes@email.com         Logística             Analista     4200

# %%
# mostra o resumo das informações da DataFrane
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   matricula     9 non-null      int64
#  1   nome          9 non-null      object
#  2   idade         9 non-null      int64
#  3   cidade        9 non-null      object
#  4   pais          9 non-null      object
#  5   email         9 non-null      object
#  6   departamento  9 non-null      object
#  7   cargo         9 non-null      object
#  8   salario       9 non-null      int64
# dtypes: int64(3), object(6)
# memory usage: 776.0+ bytes

# %%
# adicionando uma coluna ao dataframe
df['time'] = ['Corinthians', 'Flamengo', 'Santos', 'Fluminense',
              'São Paulo', 'Bahia','Gremio', 'Real Madrid', 'Fortaleza' ]
display(df)
# Out:
#    matricula               nome  idade          cidade    pais  \
# 0       1001         João Silva     29       São Paulo  Brasil
# 1       1002     Maria Oliveira     34  Rio de Janeiro  Brasil
# 2       1003       Pedro Santos     22  Belo Horizonte  Brasil
# 3       1004          Ana Costa     27        Salvador  Brasil
# 4       1005     Carlos Pereira     31       Fortaleza  Brasil
# 5       1006    Laura Rodrigues     25        Curitiba  Brasil
# 6       1007      Bruno Almeida     28    Porto Alegre  Brasil
# 7       1009    Felipe Oliveira     40        Brasília  Brasil
# 8       1010  Juliana Fernandes     26        Campinas  Brasil
#
#                          email      departamento                cargo  \
# 0         joao.silva@email.com  Recursos Humanos             Analista
# 1     maria.oliveira@email.com        Financeiro         Coordenadora
# 2       pedro.santos@email.com                TI        Desenvolvedor
# ...

# %%
df.to_csv('alunos_matriculados_tratados.csv', index=False)

# %%
df['endereco'] = ['rua1', 'rua2', 'rua3', 'rua4', 'rua5', 'rua6', 'rua7', 'rua8', 'rua9']
df['telefone'] = ['999', '888', '777', '666', '555', '444', '333', '222', '111']
df.to_csv('alunos_matriculados_tratados2.csv', index=False)

# %%
# Um conjunto de listas que irao formar um dicionario
nomes = [
    'Aline Gabriela', 'Aline Rafaela', 'Allan Christhian', 'Amanda Vieira',
    'António Lopes', 'Felipe Rangel', 'Gabriel Santana', 'Gisele dos Santos',
    'Jéssica Luana', 'João Eduardo'
]
cpfs = [
    '19560370049', '42482029058', '55003194005', '64808125064', '42868162061',
    '42868162061', '84759267034', '15588875044', '89170309043', '27904563053'
]
pesos = [
    70, 65.5, 66.6, 71, 68.7, 82.1, 80, 54, 55.9, 85.4
]
alturas = [1.80, 1.70, 1.95, 2, 1.60, 1.66, 1.78, 1.81, 1.90, 1.91]

dicionario_pessoas = {
    'nome' : nomes,
    'cpf' : cpfs,
    'peso' : pesos,
    'alttura' : alturas
}
print(dicionario_pessoas)
# criando um DataFrame
df_pessoas = pd.DataFrame(dicionario_pessoas)
display(df_pessoas)
# Out:
# {'nome': ['Aline Gabriela', 'Aline Rafaela', 'Allan Christhian', 'Amanda Vieira', 'António Lopes', 'Felipe Rangel', 'Gabriel Santana', 'Gisele dos Santos', 'Jéssica Luana', 'João Eduardo'], 'cpf': ['19560370049', '42482029058', '55003194005', '64808125064', '42868162061', '42868162061', '84759267034', '15588875044', '89170309043', '27904563053'], 'peso': [70, 65.5, 66.6, 71, 68.7, 82.1, 80, 54, 55.9, 85.4], 'alttura': [1.8, 1.7, 1.95, 2, 1.6, 1.66, 1.78, 1.81, 1.9, 1.91]}
#                 nome          cpf  peso  alttura
# 0     Aline Gabriela  19560370049  70.0     1.80
# 1      Aline Rafaela  42482029058  65.5     1.70
# 2   Allan Christhian  55003194005  66.6     1.95
# 3      Amanda Vieira  64808125064  71.0     2.00
# 4      António Lopes  42868162061  68.7     1.60
# 5      Felipe Rangel  42868162061  82.1     1.66
# 6    Gabriel Santana  84759267034  80.0     1.78
# 7  Gisele dos Santos  15588875044  54.0     1.81
# 8      Jéssica Luana  89170309043  55.9     1.90
# ...

# %%
df_pessoas.head(3)
# Out:
#                nome          cpf  peso  alttura
# 0    Aline Gabriela  19560370049  70.0     1.80
# 1     Aline Rafaela  42482029058  65.5     1.70
# 2  Allan Christhian  55003194005  66.6     1.95

# %%
df_pessoas.tail(6)
# Out:
#                 nome          cpf  peso  alttura
# 4      António Lopes  42868162061  68.7     1.60
# 5      Felipe Rangel  42868162061  82.1     1.66
# 6    Gabriel Santana  84759267034  80.0     1.78
# 7  Gisele dos Santos  15588875044  54.0     1.81
# 8      Jéssica Luana  89170309043  55.9     1.90
# 9       João Eduardo  27904563053  85.4     1.91

# %%
# Contar linhas e colunas
df_pessoas.shape
# Out:
# (10, 4)

# %%
df_pessoas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     10 non-null     object
#  1   cpf      10 non-null     object
#  2   peso     10 non-null     float64
#  3   alttura  10 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
# Criar um csv para guardar no storage
df_pessoas.to_csv('clientes_clinica.csv', index=False)

# %%
# trazer o csv do GCP
import pandas as pd
df2 = pd.read_csv('https://storage.googleapis.com/sukama-bucket/dfs_brutos/clientes_clinica.csv')
display(df)
# Out:
#                 nome          cpf  peso  alttura
# 0     Aline Gabriela  19560370049  70.0     1.80
# 1      Aline Rafaela  42482029058  65.5     1.70
# 2   Allan Christhian  55003194005  66.6     1.95
# 3      Amanda Vieira  64808125064  71.0     2.00
# 4      António Lopes  42868162061  68.7     1.60
# 5      Felipe Rangel  42868162061  82.1     1.66
# 6    Gabriel Santana  84759267034  80.0     1.78
# 7  Gisele dos Santos  15588875044  54.0     1.81
# 8      Jéssica Luana  89170309043  55.9     1.90
# 9       João Eduardo  27904563053  85.4     1.91

# %%
# Tratamento dos dados
#Criar uma coluna de IMC

df2['imc'] = round(df2['peso']/(df2['alttura']**2), 2)
display(df2)
# Out:
#                 nome          cpf  peso  alttura    imc
# 0     Aline Gabriela  19560370049  70.0     1.80  21.60
# 1      Aline Rafaela  42482029058  65.5     1.70  22.66
# 2   Allan Christhian  55003194005  66.6     1.95  17.51
# 3      Amanda Vieira  64808125064  71.0     2.00  17.75
# 4      António Lopes  42868162061  68.7     1.60  26.84
# 5      Felipe Rangel  42868162061  82.1     1.66  29.79
# 6    Gabriel Santana  84759267034  80.0     1.78  25.25
# 7  Gisele dos Santos  15588875044  54.0     1.81  16.48
# 8      Jéssica Luana  89170309043  55.9     1.90  15.48
# 9       João Eduardo  27904563053  85.4     1.91  23.41

# %%
# criar 0 csv tratado

df2.to_csv('clientes_clinica_tratado.csv', index=False)
